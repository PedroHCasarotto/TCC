# %%
import pandas as pd

# %%
result = pd.read_csv("result/test_{}_{}.csv".format('FAME_dataset', 'value'))

# %%
for i in result.preds:
    print(i)
# Out:
# ['O', '[2H]', '[2H]S', '[2H]', '[2H]O', '[2H][2H]', '[2H][N+]', '[2H]Cl', 'O=S', 'O[2H]', 'OS', 'S[2H]', '[2H]', 'SO', 'ClO', 'Cl[2H]', 'OO', 'Br[2H]', 'O', 'NO', 'O=[N+]', 'OP', 'CO', 'BrO', 'NO', '[2H]', '[2H]', 'O', '[2H]', '[2H]', '[2H]', '[C@H]O', 'OCl', 'NO', '[C@H][2H]', 'O=O', 'NO', 'Cl', 'S', 'Br', 'OBr', 'O', '[N-][2H]', 'O', '[N-]', 'Br', 'C', 'N', 'C', 'N', '[C@H]', '[NH]', '', '', '', '', '[N+]', '', 'N', '[N+]O', 'ClS', 'Cl', '[2H]', '[N-]=S', '[2H]', 'O', '[2H]', '[2H]', '[2H]', '[2H]', 'O', '[2H]', '[2H]O', '[2H]', '[2H][N+]O', '[2H]', '[2H][N+]=S', 'O', '[2H][N+][2H]', '[2H]Cl', '[2H][N+]=[N+]', '[2H]', '[2H][N+]', '[2H][N+]', '[2H]Cl', 'C[2H]', '[2H]Cl', '[2H]Cl', '[2H][N+]P', 'CO', '[2H]Cl', '[2H]Cl', '[2H]Cl', '[2H][N+]Cl', '[2H]Cl', '[2H]', '[2H]OO', '[2H]Cl', '[2H]O', '[2H]O', '[2H]', 'OP[2H]', '[2H][2H]', 'OP=S', '[2H]S', '[2H]', 'OP[C@@H]', 'O=O', '[2H]', '[2H]', '[2H]Cl', 'OCl', 'OPO', '[2H]', 'OCl', '[2H]P', '[2H]NO', '[2H]', '[2H]', 'OCl', '[2H]', '[2H]', '
# ...

# %%
result_2 = pd.read_csv("result/test_{}_{}.csv".format('FAME_dataset', 'value'))

# %%
result_2
# Out:
#         ID                                              preds  valid  \
# 0  sample0  ['', '[O-]', '[C@@H]', '[2H]', 'S', 'S', 'N', ...  0.999
# 1  sample1  ['', '[O-]', '[C@@H]', '[2H]', 'S', 'S', 'C', ...  0.999
# 2  sample2  ['', '[O-]', '[C@@H]', '[2H]', 'S', 'S', 'C', ...  0.999
#
#      unique       div   qed_mid  \
# 0  0.454788  0.973114  0.485925
# 1  0.450450  0.972445  0.485925
# 2  0.448115  0.972456  0.485925
#
#                                                  qed      mw_mid  \
# 0  [0.5105094687951879, 0.5050781538986456, 0.499...  181.529551
# 1  [0.5105094687951879, 0.5050781538986456, 0.499...  186.539551
# 2  [0.5105094687951879, 0.5050781538986456, 0.499...  181.529551
#
#                                                   mw     sa_mid         sa
# 0  [192.046, 191.977, 188.065, 187.989, 185.09010...  See after  See after
# 1  [192.046, 191.977, 188.065, 187.989, 187.989, ...  See after  See after
# ...

# %%
result_3 = pd.read_csv("result/test_{}_{}.csv".format('FAME_dataset', 'one_hot'))

# %%
for i in result_3.preds:
    print(i)
# Out:
# ['', 'Br', 'O', 'S', '', 'OBr', 'OO', 'O', 'O', 'OI', 'O/S', 'SO', 'OC', 'O[S@@]', 'S/[C@H]', 'S', 'O=S', 'SC', 'Br', 'S', 'O=N', 'O[C@]', 'Br/[C@H]', 'BrO', 'O', 'Br', 'S/S', 'BrC', 'O', 'Br/S', '', 'S=O', 'S', 'BrI', 'Br/O', 'O/S', 'BrS', '', 'S[2H]', 'S', 'Br[N+]', '', 'Br[2H]', '[S@@]', '', 'Br', 'BrN', 'N', 'S', '[N+]', 'Br[C@]', '', 'C', 'OC', '[S@@]', 'C', '', 'OBr', '[S@@]O', 'O/N', '', '[C@H]', 'OO', '[S@@]', '[2H]', '', '[S@@]', 'O', 'O', '[N+]', 'O', '', 'O', 'N', 'O[S@@]', '[C@]', 'N', '[S@@]/S', '[S@@]', '[S@@]/[C@H]', '[C@H]', '', 'O[2H]', '[S@@]I', 'N', 'I', 'C', 'O', 'S', '', '', 'N', 'O', '[S@@][C@]', '[N+]O', '[N+]', '[S@@]C', '[C@H]', '[N+]', 'O/O', '[2H]', '[N+][S@@]', '[C@H]O', '[N+]/N', 'O/[C@H]', '[2H]Br', 'N/N', 'N', 'N', '[N+]', 'N', 'O', 'S', '[2H]/N', 'NI', '[C@H][C@]', '[C@H]', 'NO', '[N+]C', '[2H]I', 'BrB', '[N+][C@]', '[C@H]', '[C@H]', '[C@H][S@@]', '[S@@][N+]', 'C', '[C@H]=S', '[S@@]', 'N', 'O=N', '[C@H]/O', '[NH]O', '[2H]', 'Br', 'N', 'NC', '[C@H]C', '
# ...

# %% [markdown]
# ### Analyse Transgem also generated

# %%
result_4 = pd.read_csv("result/test_{}_{}.csv".format('subLINCS', 'value'))

# %%
for i in result_4.preds:print(i)
# Out:
# ['CCCCCCCCC', 'CCCCCCCCCC', 'CCCCCCCC', 'CCCCCCCCCCC', 'CCCCCCCCCCCC', 'CCCCCCC', 'CCCCCCCCCCCCC', 'CCCCCCCCCCCCCC', 'CCCCCC', 'CCCCCCCCCCCCCCC', 'CCCCCCCCCCCCCCCC', 'C1OC=C1', 'CCCCC', 'CCCCCCCCCCCCCCCCC', 'CCCCCCCCCCCCCCCCCC', 'CCCCCCCCCCCCCCCCCCC', 'CCCC', 'CCCCCCCCCCCCCCCCCCCC', 'C1OC=C1', 'CCCCCCCCCCCCCCCCCCCCC', 'CCCCCCCCCCCCCCCCCCCCCC', 'CCCCCCCCCCCCCCCCCCCCCCC', 'CCCCCCCCCCCCCCCCCCCCCCCC', 'COC=C', 'CCCCCCCCCCCCCCCCCCCCCCCCC', 'O1C=C1', 'CCC', 'CCCCCCCCCCCCCCCCCCCCCCCCCC', 'CCCCCCCCCCCCCCCCCCCCCCCCCCC', 'C1OC=CC=C1', 'CCCCCCCCCCCCCCCCCCCCCCCCCCCC', 'CCCCCCCCCCCCCCCCCCCCCCCCCCCCC', 'CCCCCCCCCCCCCCCCCCCCCCCCCCCCCC', 'CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC', 'C1OC=C1', 'CCCCCCCCCCCCCC=C', 'CCCCCCCCCCCCC=C', 'CCCCCCCCCCCCCCC=C', 'CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC', 'CCCCCCCCCCCC=C', 'CCCCCCCCCCCCCCCC=C', 'CCCCCCCCCCCCCC=CC', 'CCCCCCCCCCCCCCCCC=C', 'CCCCCCCCCCCCC=CC', 'CCCCCCCCCCCCCCC=CC', 'CCCCCCCCCCC=C', 'CCCCCCCCCCCCCCCC=CC', 'CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC', 'CCCCCCCCCCCC=CC', 'CCC
# ...

# %%
result_3
# Out:
#         ID                                              preds     valid  \
# 0  sample0  ['', 'Br', 'O', 'S', '', 'OBr', 'OO', 'O', 'O'...  0.998667
# 1  sample1  ['', 'Br', 'N', 'I', 'O', 'S', 'OBr', 'OO', 'O...  0.998667
#
#      unique       div   qed_mid  \
# 0  0.454940  0.965900  0.571305
# 1  0.501001  0.971844  0.595374
#
#                                                  qed   mw_mid  \
# 0  [0.6449608383865238, 0.627857377900558, 0.5949...  191.875
# 1  [0.6703089799245858, 0.6312574940015305, 0.627...  265.819
#
#                                                   mw     sa_mid         sa
# 0  [220.05599999999998, 208.045, 206.808, 192.046...  See after  See after
# 1  [297.88599999999997, 281.894, 269.807, 268.823...  See after  See after

# %%
result_5 = pd.read_csv("result/test_{}_{}.csv".format('FAME_dataset', 'one_hot'))

# %%
result_5
# Out:
#         ID                                              preds  valid  unique  \
# 0  sample0  ['O', 'S', 'Br', 'C', '', '[C@]', '', '', '[Si...    1.0   0.384
# 1  sample1  ['O', 'S', 'Br', '', 'C', '', '[C@]', '[Si]', ...    1.0   0.380
#
#         div   qed_mid                                                qed  \
# 0  0.956703  0.511744  [0.5844243841318096, 0.5776074734119597, 0.530...
# 1  0.956975  0.511744  [0.5844243841318096, 0.5776074734119597, 0.530...
#
#      mw_mid                                                 mw     sa_mid  \
# 0  191.9610  [253.808, 238.875, 221.82299999999998, 206.808...  See after
# 1  199.3845  [253.808, 238.875, 238.79, 221.82299999999998,...  See after
#
#           sa
# 0  See after
# 1  See after

# %%
for i in result_5.preds:print(i)
# Out:
# ['O', 'S', 'Br', 'C', '', '[C@]', '', '', '[Si]', '', 'I', '[S@@]', '[O-]', 'Cl', '', '', 'P', 'C', '', '[C@@H]', 'C', '[C@@H][C@H]', '[C@@H]#[C-]', 'C', '[C@@H]=[N+]', 'C[C@H]', 'C#[C-]', 'C', '[C@@H]I', '[C@@H]', 'C=[N+]', 'P[C@H]', 'PI', 'C', '[C@@H]', 'C[C@]', '[C@@H][S@@]', 'P#[C-]', 'C/O', 'C[S@@]', 'P', '[C@@H]F', '[C@@H]#N', 'P', 'CBr', 'P/[C@H]', '[C@@H][C@]', '[C@H]', 'CF', '[C-]', 'C[O-]', 'P[O-]', 'PO', '[C@H]', 'P=[N+]', '[C@@H][O-]', '[C-]', 'C[Si]', 'P', 'CI', '[C@H]', 'PF', 'P#N', '[C@H]', 'PCl', 'P', '', '[C@@H]', '[C@@H]', 'I', '[O-]', 'P[C@@H]', 'Cl', '[N+][C@H]', '[N+]', '[C@@H]', '[N+]', '', '[N+][O-]', '[O-]', '[N+][C@@H]', '[N+]=[N+]', 'I', 'C', '[N+]#[C-]', '[N+]/[C@H]', '[N+]', 'C', '[C@H]', '', '[N+]', '[O-]O', '', 'C[C@H]', '', '[N+]#C', 'C#[C-]', '[S@@]', '[O-]/[C@H]', '[C@@H]', '[O-]', 'N/[C@H]', '[N+]Br', '', '[N+]Cl', 'C', '[C-]', 'C[C@@H]', 'I[Si]', '[N+]', 'S', '[Si]', '', '[S@@]', 'N', 'N=[N+]', 'O', '[C@]', 'Br', 'BrC', '[C@][Si]', 'N', 'N', '[C@]/O
# ...
